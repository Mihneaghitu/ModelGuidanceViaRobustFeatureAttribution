# %%
# %load_ext autoreload
# %autoreload 2
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision import datasets
from torch.utils.data import DataLoader, TensorDataset
import abstract_gradient_training as agt
from abstract_gradient_training import certified_training_utils as ct_utils
from abstract_gradient_training import test_metrics
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np
import os
import copy
import seaborn as sns
import matplotlib as mpl
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
num_components = 32  # Number of principal components to keep

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
mnist_train = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
mnist_test = datasets.MNIST(root='./data', train=False, transform=transform, download=True)

train_imgs = mnist_train.data
train_imgs = train_imgs.view(train_imgs.shape[0], -1).numpy() / 255.0
test_imgs = mnist_test.data
test_imgs = test_imgs.view(test_imgs.shape[0], -1).numpy() / 255.0

pca = PCA(n_components=num_components)
pca.fit_transform(train_imgs)
pc_train = pca.transform(train_imgs)
pc_test = pca.transform(test_imgs)

# %%
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance_ratio)
plt.figure(figsize=(8, 5))
plt.plot(cumulative_explained_variance, marker='o', linestyle='--', color='b')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance vs Number of Principal Components')
plt.grid(True)
plt.show()

# %%
# configure the training parameters
batchsize = 60000
train_dataset = TensorDataset(torch.tensor(pc_train, dtype=torch.float32), torch.tensor(mnist_train.targets, dtype=torch.long))
test_dataset = TensorDataset(torch.tensor(pc_test, dtype=torch.float32), torch.tensor(mnist_test.targets, dtype=torch.long))

idx = np.random.permutation(len(train_dataset))
train_dataset = TensorDataset(train_dataset.tensors[0][idx].double(), train_dataset.tensors[1][idx])
idx = np.random.permutation(len(test_dataset))
test_dataset = TensorDataset(test_dataset.tensors[0][idx].double(), test_dataset.tensors[1][idx])

dl_train = DataLoader(train_dataset, batch_size=batchsize, shuffle=False)
dl_test = DataLoader(test_dataset, batch_size=1000, shuffle=False)

nominal_config = agt.AGTConfig(
    fragsize=5000,
    learning_rate=5.0,
    lr_decay=1.0,
    lr_min=0.001,
    # label_k_poison=1,
    n_epochs=2,
    device="cuda:1",
    forward_bound="interval",
    backward_bound="interval",
    # clip_gamma=0.1,
    # poison_target=1,
    loss="cross_entropy",
    early_stopping=False,
    log_level="DEBUG",
    bound_kwargs={"interval_matmul": "exact"}
)
torch.manual_seed(0)
model = nn.Sequential(
    nn.Linear(num_components, 10),
).to(config.device).double()

conf = copy.deepcopy(nominal_config)
conf.n_epochs = 10

# train the model
param_l, param_n, param_u = agt.poison_certified_training(model, conf, dl_train, dl_test)
# Out:
# /tmp/ipykernel_509632/1364082244.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_dataset = TensorDataset(torch.tensor(pc_train, dtype=torch.float32), torch.tensor(mnist_train.targets, dtype=torch.long))
# /tmp/ipykernel_509632/1364082244.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_dataset = TensorDataset(torch.tensor(pc_test, dtype=torch.float32), torch.tensor(mnist_test.targets, dtype=torch.long))
# [AGT] [INFO    ] [01:59:56] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [01:59:56] 	Optimizer params: n_epochs=10, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [01:59:56] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [01:59:56] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [01:59:56] 	Adversary label-space budget: label_epsilon=0, label_k_poison=0, poison_target=-1
# [AGT] [DEBUG   ] [01:59:56] 	Clipping: gamma=inf, method=clamp
# [AGT] [DEBUG   ] [01:59:56] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [01:59:56] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [01:59:56] Starting epoch 1
# [AGT] [DEBUG   ] [01:59:57] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [01:59:57] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [01:59:57] Starting epoch 2
# [AGT] [INFO    ] [01:59:58] Training batch 2: Network eval bounds=(0.73, 0.73, 0.73), W0 Bound=0.0
# [AGT] [INFO    ] [01:59:58] Starting epoch 3
# [AGT] [INFO    ] [01:59:59] Training batch 3: Network eval bounds=(0.8 , 0.8 , 0.8 ), W0 Bound=0.0
# [AGT] [INFO    ] [01:59:59] Starting epoch 4
# [AGT] [INFO    ] [02:00:00] Training batch 4: Network eval bounds=(0.83, 0.83, 0.83), W0 Bound=0.0
# [AGT] [INFO    ] [02:00:00] Starting epoch 5
# [AGT] [INFO    ] [02:00:01] Training batch 5: Network eval bounds=(0.85, 0.85, 0.85), W0 Bound=0.0
# [AGT] [INFO    ] [02:00:01] Starting epoch 6
# [AGT] [INFO    ] [02:00:02] Training batch 6: Network eval bounds=(0.84, 0.84, 0.84), W0 Bound=0.0
# [AGT] [INFO    ] [02:00:02] Starting epoch 7
# [AGT] [INFO    ] [02:00:03] Training batch 7: Network eval bounds=(0.85, 0.85, 0.85), W0 Bound=0.0
# [AGT] [INFO    ] [02:00:03] Starting epoch 8
# [AGT] [INFO    ] [02:00:04] Training batch 8: Network eval bounds=(0.85, 0.85, 0.85), W0 Bound=0.0
# [AGT] [INFO    ] [02:00:04] Starting epoch 9
# [AGT] [INFO    ] [02:00:05] Training batch 9: Network eval bounds=(0.86, 0.86, 0.86), W0 Bound=0.0
# [AGT] [INFO    ] [02:00:05] Starting epoch 10
# [AGT] [INFO    ] [02:00:06] Training batch 10: Network eval bounds=(0.83, 0.83, 0.83), W0 Bound=0.0
# [AGT] [INFO    ] [02:00:06] Final network eval: Network eval bounds=(0.87, 0.87, 0.87), W0 Bound=0.0
# [AGT] [INFO    ] [02:00:06] =================== Finished Poison Certified Training ===================

# %%
results_dir = ".results/"
seed = 5
notebook_id = f"mnist_poison_{seed}"

def run_with_config(config):
    """If results for this configuration are already computed, load them from disk. Otherwise, run the certified
    training using AGT, then save and return the results."""
    fname = f"{results_dir}/{notebook_id}_{config.hash()}"
    if os.path.isfile(fname):  # run exists, so return the previous results
        param_l, param_n, param_u = torch.load(fname)
    else:
        # check whether the given config should be either unlearning or privacy training
        assert not (config.k_unlearn and config.k_private)
        torch.manual_seed(seed)
        param_l, param_n, param_u = agt.poison_certified_training(
            model, config, dl_train, dl_test, transform=ct_utils.propagate_conv_layers
        )
        torch.save((param_l, param_n, param_u), fname)
    # get nominal accuracy (on the Drusen class) and percent certified (on the entire test set)
    accuracy = test_metrics.test_accuracy(
        param_n, param_l, param_u, *next(iter(dl_test)), model, ct_utils.propagate_conv_layers
    )
    del param_l, param_n, param_u
    torch.cuda.empty_cache()
    return accuracy

# %%
# experiment 1
k_poisons = list(range(0, 101, 5))
clip_gammas = [np.inf, 0.2, 0.1]

results = {}

config = copy.deepcopy(nominal_config)

for gamma in clip_gammas:
    tmp_results = {}
    for k_poison in k_poisons:
        config.label_k_poison = k_poison
        config.clip_gamma = gamma
        tmp_results[k_poison] = run_with_config(config)
    results[gamma] = tmp_results
# Out:
# [AGT] [INFO    ] [02:12:08] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:08] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:08] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:08] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:08] 	Adversary label-space budget: label_epsilon=0, label_k_poison=5, poison_target=-1
# [AGT] [DEBUG   ] [02:12:08] 	Clipping: gamma=inf, method=clamp
# [AGT] [DEBUG   ] [02:12:08] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:08] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:08] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:09] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:09] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:09] Starting epoch 2
# [AGT] [INFO    ] [02:12:10] Training batch 2: Network eval bounds=(0.72, 0.73, 0.74), W0 Bound=0.0588
# [AGT] [INFO    ] [02:12:10] Final network eval: Network eval bounds=(0.76, 0.8 , 0.84), W0 Bound=0.298
# [AGT] [INFO    ] [02:12:10] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:10] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:10] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:10] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:10] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:10] 	Adversary label-space budget: label_epsilon=0, label_k_poison=15, poison_target=-1
# [AGT] [DEBUG   ] [02:12:10] 	Clipping: gamma=inf, method=clamp
# [AGT] [DEBUG   ] [02:12:10] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:10] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:10] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:11] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:11] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:11] Starting epoch 2
# [AGT] [INFO    ] [02:12:13] Training batch 2: Network eval bounds=(0.71, 0.73, 0.75), W0 Bound=0.168
# [AGT] [INFO    ] [02:12:13] Final network eval: Network eval bounds=(0.63, 0.8 , 0.9 ), W0 Bound=0.852
# [AGT] [INFO    ] [02:12:13] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:13] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:13] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:13] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:13] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:13] 	Adversary label-space budget: label_epsilon=0, label_k_poison=25, poison_target=-1
# [AGT] [DEBUG   ] [02:12:13] 	Clipping: gamma=inf, method=clamp
# [AGT] [DEBUG   ] [02:12:13] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:13] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:13] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:14] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:14] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:14] Starting epoch 2
# [AGT] [INFO    ] [02:12:15] Training batch 2: Network eval bounds=(0.69, 0.73, 0.77), W0 Bound=0.271
# [AGT] [INFO    ] [02:12:15] Final network eval: Network eval bounds=(0.5 , 0.8 , 0.94), W0 Bound=1.38
# [AGT] [INFO    ] [02:12:15] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:15] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:15] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:15] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:15] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:15] 	Adversary label-space budget: label_epsilon=0, label_k_poison=35, poison_target=-1
# [AGT] [DEBUG   ] [02:12:15] 	Clipping: gamma=inf, method=clamp
# [AGT] [DEBUG   ] [02:12:15] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:15] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:15] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:16] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:16] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:16] Starting epoch 2
# [AGT] [INFO    ] [02:12:17] Training batch 2: Network eval bounds=(0.67, 0.73, 0.79), W0 Bound=0.372
# [AGT] [INFO    ] [02:12:17] Final network eval: Network eval bounds=(0.37, 0.8 , 0.96), W0 Bound=1.9
# [AGT] [INFO    ] [02:12:17] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:17] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:17] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:17] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:17] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:17] 	Adversary label-space budget: label_epsilon=0, label_k_poison=45, poison_target=-1
# [AGT] [DEBUG   ] [02:12:17] 	Clipping: gamma=inf, method=clamp
# [AGT] [DEBUG   ] [02:12:17] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:17] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:17] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:18] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:18] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:18] Starting epoch 2
# [AGT] [INFO    ] [02:12:19] Training batch 2: Network eval bounds=(0.65, 0.73, 0.8 ), W0 Bound=0.471
# [AGT] [INFO    ] [02:12:19] Final network eval: Network eval bounds=(0.29, 0.8 , 0.98), W0 Bound=2.41
# [AGT] [INFO    ] [02:12:19] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:19] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:19] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:19] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:19] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:19] 	Adversary label-space budget: label_epsilon=0, label_k_poison=55, poison_target=-1
# [AGT] [DEBUG   ] [02:12:19] 	Clipping: gamma=inf, method=clamp
# [AGT] [DEBUG   ] [02:12:19] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:19] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:19] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:20] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:20] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:20] Starting epoch 2
# [AGT] [INFO    ] [02:12:21] Training batch 2: Network eval bounds=(0.64, 0.73, 0.82), W0 Bound=0.568
# [AGT] [INFO    ] [02:12:21] Final network eval: Network eval bounds=(0.22, 0.8 , 0.99), W0 Bound=2.92
# [AGT] [INFO    ] [02:12:21] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:21] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:21] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:21] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:21] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:21] 	Adversary label-space budget: label_epsilon=0, label_k_poison=65, poison_target=-1
# [AGT] [DEBUG   ] [02:12:21] 	Clipping: gamma=inf, method=clamp
# [AGT] [DEBUG   ] [02:12:21] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:21] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:21] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:22] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:22] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:22] Starting epoch 2
# [AGT] [INFO    ] [02:12:23] Training batch 2: Network eval bounds=(0.62, 0.73, 0.83), W0 Bound=0.664
# [AGT] [INFO    ] [02:12:23] Final network eval: Network eval bounds=(0.18, 0.8 , 1   ), W0 Bound=3.42
# [AGT] [INFO    ] [02:12:23] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:23] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:23] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:23] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:23] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:23] 	Adversary label-space budget: label_epsilon=0, label_k_poison=75, poison_target=-1
# [AGT] [DEBUG   ] [02:12:23] 	Clipping: gamma=inf, method=clamp
# [AGT] [DEBUG   ] [02:12:23] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:23] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:23] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:24] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:24] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:24] Starting epoch 2
# [AGT] [INFO    ] [02:12:25] Training batch 2: Network eval bounds=(0.6 , 0.73, 0.84), W0 Bound=0.758
# [AGT] [INFO    ] [02:12:25] Final network eval: Network eval bounds=(0.13, 0.8 , 1   ), W0 Bound=3.92
# [AGT] [INFO    ] [02:12:25] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:25] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:25] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:25] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:25] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:25] 	Adversary label-space budget: label_epsilon=0, label_k_poison=85, poison_target=-1
# [AGT] [DEBUG   ] [02:12:25] 	Clipping: gamma=inf, method=clamp
# [AGT] [DEBUG   ] [02:12:25] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:25] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:25] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:26] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:26] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:26] Starting epoch 2
# [AGT] [INFO    ] [02:12:27] Training batch 2: Network eval bounds=(0.59, 0.73, 0.84), W0 Bound=0.852
# [AGT] [INFO    ] [02:12:27] Final network eval: Network eval bounds=(0.089, 0.8 , 1   ), W0 Bound=4.43
# [AGT] [INFO    ] [02:12:27] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:27] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:27] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:27] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:27] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:27] 	Adversary label-space budget: label_epsilon=0, label_k_poison=95, poison_target=-1
# [AGT] [DEBUG   ] [02:12:27] 	Clipping: gamma=inf, method=clamp
# [AGT] [DEBUG   ] [02:12:27] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:27] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:27] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:28] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:28] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:28] Starting epoch 2
# [AGT] [INFO    ] [02:12:29] Training batch 2: Network eval bounds=(0.57, 0.73, 0.85), W0 Bound=0.944
# [AGT] [INFO    ] [02:12:29] Final network eval: Network eval bounds=(0.061, 0.8 , 1   ), W0 Bound=4.93
# [AGT] [INFO    ] [02:12:29] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:29] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:29] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:29] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:29] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:29] 	Adversary label-space budget: label_epsilon=0, label_k_poison=5, poison_target=-1
# [AGT] [DEBUG   ] [02:12:29] 	Clipping: gamma=0.2, method=clamp
# [AGT] [DEBUG   ] [02:12:29] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:29] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:29] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:30] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:30] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:31] Starting epoch 2
# [AGT] [INFO    ] [02:12:31] Training batch 2: Network eval bounds=(0.64, 0.65, 0.65), W0 Bound=0.00596
# [AGT] [INFO    ] [02:12:31] Final network eval: Network eval bounds=(0.71, 0.73, 0.76), W0 Bound=0.0424
# [AGT] [INFO    ] [02:12:31] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:31] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:31] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:31] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:31] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:31] 	Adversary label-space budget: label_epsilon=0, label_k_poison=15, poison_target=-1
# [AGT] [DEBUG   ] [02:12:31] 	Clipping: gamma=0.2, method=clamp
# [AGT] [DEBUG   ] [02:12:31] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:31] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:31] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:32] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:32] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:32] Starting epoch 2
# [AGT] [INFO    ] [02:12:33] Training batch 2: Network eval bounds=(0.62, 0.65, 0.67), W0 Bound=0.0179
# [AGT] [INFO    ] [02:12:33] Final network eval: Network eval bounds=(0.65, 0.73, 0.79), W0 Bound=0.127
# [AGT] [INFO    ] [02:12:33] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:33] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:33] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:33] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:33] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:33] 	Adversary label-space budget: label_epsilon=0, label_k_poison=25, poison_target=-1
# [AGT] [DEBUG   ] [02:12:33] 	Clipping: gamma=0.2, method=clamp
# [AGT] [DEBUG   ] [02:12:33] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:33] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:33] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:34] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:34] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:35] Starting epoch 2
# [AGT] [INFO    ] [02:12:35] Training batch 2: Network eval bounds=(0.61, 0.65, 0.68), W0 Bound=0.0298
# [AGT] [INFO    ] [02:12:35] Final network eval: Network eval bounds=(0.6 , 0.73, 0.84), W0 Bound=0.212
# [AGT] [INFO    ] [02:12:35] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:35] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:35] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:35] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:35] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:35] 	Adversary label-space budget: label_epsilon=0, label_k_poison=35, poison_target=-1
# [AGT] [DEBUG   ] [02:12:35] 	Clipping: gamma=0.2, method=clamp
# [AGT] [DEBUG   ] [02:12:35] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:35] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:35] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:36] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:36] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:37] Starting epoch 2
# [AGT] [INFO    ] [02:12:37] Training batch 2: Network eval bounds=(0.61, 0.65, 0.69), W0 Bound=0.0417
# [AGT] [INFO    ] [02:12:37] Final network eval: Network eval bounds=(0.53, 0.73, 0.87), W0 Bound=0.297
# [AGT] [INFO    ] [02:12:37] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:37] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:37] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:37] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:37] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:37] 	Adversary label-space budget: label_epsilon=0, label_k_poison=45, poison_target=-1
# [AGT] [DEBUG   ] [02:12:37] 	Clipping: gamma=0.2, method=clamp
# [AGT] [DEBUG   ] [02:12:37] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:37] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:37] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:39] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:39] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:39] Starting epoch 2
# [AGT] [INFO    ] [02:12:40] Training batch 2: Network eval bounds=(0.6 , 0.65, 0.7 ), W0 Bound=0.0537
# [AGT] [INFO    ] [02:12:40] Final network eval: Network eval bounds=(0.47, 0.73, 0.9 ), W0 Bound=0.381
# [AGT] [INFO    ] [02:12:40] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:40] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:40] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:40] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:40] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:40] 	Adversary label-space budget: label_epsilon=0, label_k_poison=55, poison_target=-1
# [AGT] [DEBUG   ] [02:12:40] 	Clipping: gamma=0.2, method=clamp
# [AGT] [DEBUG   ] [02:12:40] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:40] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:40] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:41] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:41] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:41] Starting epoch 2
# [AGT] [INFO    ] [02:12:42] Training batch 2: Network eval bounds=(0.6 , 0.65, 0.7 ), W0 Bound=0.0656
# [AGT] [INFO    ] [02:12:42] Final network eval: Network eval bounds=(0.42, 0.73, 0.91), W0 Bound=0.466
# [AGT] [INFO    ] [02:12:42] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:42] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:42] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:42] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:42] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:42] 	Adversary label-space budget: label_epsilon=0, label_k_poison=65, poison_target=-1
# [AGT] [DEBUG   ] [02:12:42] 	Clipping: gamma=0.2, method=clamp
# [AGT] [DEBUG   ] [02:12:42] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:42] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:42] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:43] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:43] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:43] Starting epoch 2
# [AGT] [INFO    ] [02:12:44] Training batch 2: Network eval bounds=(0.59, 0.65, 0.71), W0 Bound=0.0775
# [AGT] [INFO    ] [02:12:44] Final network eval: Network eval bounds=(0.37, 0.73, 0.94), W0 Bound=0.551
# [AGT] [INFO    ] [02:12:44] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:44] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:44] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:44] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:44] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:44] 	Adversary label-space budget: label_epsilon=0, label_k_poison=75, poison_target=-1
# [AGT] [DEBUG   ] [02:12:44] 	Clipping: gamma=0.2, method=clamp
# [AGT] [DEBUG   ] [02:12:44] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:44] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:44] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:45] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:45] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:45] Starting epoch 2
# [AGT] [INFO    ] [02:12:46] Training batch 2: Network eval bounds=(0.58, 0.65, 0.72), W0 Bound=0.0894
# [AGT] [INFO    ] [02:12:46] Final network eval: Network eval bounds=(0.32, 0.73, 0.95), W0 Bound=0.635
# [AGT] [INFO    ] [02:12:46] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:46] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:46] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:46] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:46] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:46] 	Adversary label-space budget: label_epsilon=0, label_k_poison=85, poison_target=-1
# [AGT] [DEBUG   ] [02:12:46] 	Clipping: gamma=0.2, method=clamp
# [AGT] [DEBUG   ] [02:12:46] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:46] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:46] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:47] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:47] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:47] Starting epoch 2
# [AGT] [INFO    ] [02:12:48] Training batch 2: Network eval bounds=(0.57, 0.65, 0.73), W0 Bound=0.101
# [AGT] [INFO    ] [02:12:48] Final network eval: Network eval bounds=(0.28, 0.73, 0.97), W0 Bound=0.719
# [AGT] [INFO    ] [02:12:48] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:48] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:48] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:48] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:48] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:48] 	Adversary label-space budget: label_epsilon=0, label_k_poison=95, poison_target=-1
# [AGT] [DEBUG   ] [02:12:48] 	Clipping: gamma=0.2, method=clamp
# [AGT] [DEBUG   ] [02:12:48] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:48] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:48] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:49] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:49] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:49] Starting epoch 2
# [AGT] [INFO    ] [02:12:50] Training batch 2: Network eval bounds=(0.56, 0.65, 0.74), W0 Bound=0.113
# [AGT] [INFO    ] [02:12:50] Final network eval: Network eval bounds=(0.24, 0.73, 0.98), W0 Bound=0.804
# [AGT] [INFO    ] [02:12:50] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:50] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:50] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:50] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:50] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:50] 	Adversary label-space budget: label_epsilon=0, label_k_poison=5, poison_target=-1
# [AGT] [DEBUG   ] [02:12:50] 	Clipping: gamma=0.1, method=clamp
# [AGT] [DEBUG   ] [02:12:50] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:50] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:50] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:51] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:51] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:51] Starting epoch 2
# [AGT] [INFO    ] [02:12:52] Training batch 2: Network eval bounds=(0.43, 0.44, 0.44), W0 Bound=0.00298
# [AGT] [INFO    ] [02:12:52] Final network eval: Network eval bounds=(0.54, 0.55, 0.56), W0 Bound=0.014
# [AGT] [INFO    ] [02:12:52] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:52] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:52] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:52] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:52] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:52] 	Adversary label-space budget: label_epsilon=0, label_k_poison=15, poison_target=-1
# [AGT] [DEBUG   ] [02:12:52] 	Clipping: gamma=0.1, method=clamp
# [AGT] [DEBUG   ] [02:12:52] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:52] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:52] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:53] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:53] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:53] Starting epoch 2
# [AGT] [INFO    ] [02:12:54] Training batch 2: Network eval bounds=(0.43, 0.44, 0.44), W0 Bound=0.00894
# [AGT] [INFO    ] [02:12:54] Final network eval: Network eval bounds=(0.52, 0.55, 0.58), W0 Bound=0.042
# [AGT] [INFO    ] [02:12:54] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:54] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:54] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:54] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:54] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:54] 	Adversary label-space budget: label_epsilon=0, label_k_poison=25, poison_target=-1
# [AGT] [DEBUG   ] [02:12:54] 	Clipping: gamma=0.1, method=clamp
# [AGT] [DEBUG   ] [02:12:54] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:54] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:54] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:55] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:55] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:55] Starting epoch 2
# [AGT] [INFO    ] [02:12:57] Training batch 2: Network eval bounds=(0.43, 0.44, 0.45), W0 Bound=0.0149
# [AGT] [INFO    ] [02:12:57] Final network eval: Network eval bounds=(0.49, 0.55, 0.6 ), W0 Bound=0.07
# [AGT] [INFO    ] [02:12:57] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:57] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:57] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:57] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:57] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:57] 	Adversary label-space budget: label_epsilon=0, label_k_poison=35, poison_target=-1
# [AGT] [DEBUG   ] [02:12:57] 	Clipping: gamma=0.1, method=clamp
# [AGT] [DEBUG   ] [02:12:57] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:57] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:57] Starting epoch 1
# [AGT] [DEBUG   ] [02:12:58] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:12:58] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:12:58] Starting epoch 2
# [AGT] [INFO    ] [02:12:59] Training batch 2: Network eval bounds=(0.42, 0.44, 0.46), W0 Bound=0.0209
# [AGT] [INFO    ] [02:12:59] Final network eval: Network eval bounds=(0.47, 0.55, 0.62), W0 Bound=0.0981
# [AGT] [INFO    ] [02:12:59] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:12:59] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:12:59] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:12:59] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:12:59] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:12:59] 	Adversary label-space budget: label_epsilon=0, label_k_poison=45, poison_target=-1
# [AGT] [DEBUG   ] [02:12:59] 	Clipping: gamma=0.1, method=clamp
# [AGT] [DEBUG   ] [02:12:59] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:12:59] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:12:59] Starting epoch 1
# [AGT] [DEBUG   ] [02:13:00] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:13:00] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:13:00] Starting epoch 2
# [AGT] [INFO    ] [02:13:01] Training batch 2: Network eval bounds=(0.42, 0.44, 0.47), W0 Bound=0.0268
# [AGT] [INFO    ] [02:13:01] Final network eval: Network eval bounds=(0.45, 0.55, 0.64), W0 Bound=0.126
# [AGT] [INFO    ] [02:13:01] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:13:01] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:13:01] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:13:01] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:13:01] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:13:01] 	Adversary label-space budget: label_epsilon=0, label_k_poison=55, poison_target=-1
# [AGT] [DEBUG   ] [02:13:01] 	Clipping: gamma=0.1, method=clamp
# [AGT] [DEBUG   ] [02:13:01] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:13:01] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:13:01] Starting epoch 1
# [AGT] [DEBUG   ] [02:13:02] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:13:02] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:13:03] Starting epoch 2
# [AGT] [INFO    ] [02:13:03] Training batch 2: Network eval bounds=(0.41, 0.44, 0.47), W0 Bound=0.0328
# [AGT] [INFO    ] [02:13:03] Final network eval: Network eval bounds=(0.43, 0.55, 0.66), W0 Bound=0.154
# [AGT] [INFO    ] [02:13:03] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:13:04] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:13:04] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:13:04] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:13:04] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:13:04] 	Adversary label-space budget: label_epsilon=0, label_k_poison=65, poison_target=-1
# [AGT] [DEBUG   ] [02:13:04] 	Clipping: gamma=0.1, method=clamp
# [AGT] [DEBUG   ] [02:13:04] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:13:04] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:13:04] Starting epoch 1
# [AGT] [DEBUG   ] [02:13:05] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:13:05] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:13:05] Starting epoch 2
# [AGT] [INFO    ] [02:13:06] Training batch 2: Network eval bounds=(0.41, 0.44, 0.48), W0 Bound=0.0388
# [AGT] [INFO    ] [02:13:06] Final network eval: Network eval bounds=(0.41, 0.55, 0.69), W0 Bound=0.182
# [AGT] [INFO    ] [02:13:06] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:13:06] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:13:06] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:13:06] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:13:06] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:13:06] 	Adversary label-space budget: label_epsilon=0, label_k_poison=75, poison_target=-1
# [AGT] [DEBUG   ] [02:13:06] 	Clipping: gamma=0.1, method=clamp
# [AGT] [DEBUG   ] [02:13:06] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:13:06] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:13:06] Starting epoch 1
# [AGT] [DEBUG   ] [02:13:07] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:13:07] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:13:07] Starting epoch 2
# [AGT] [INFO    ] [02:13:08] Training batch 2: Network eval bounds=(0.4 , 0.44, 0.48), W0 Bound=0.0447
# [AGT] [INFO    ] [02:13:08] Final network eval: Network eval bounds=(0.39, 0.55, 0.71), W0 Bound=0.21
# [AGT] [INFO    ] [02:13:08] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:13:08] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:13:08] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:13:08] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:13:08] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:13:08] 	Adversary label-space budget: label_epsilon=0, label_k_poison=85, poison_target=-1
# [AGT] [DEBUG   ] [02:13:08] 	Clipping: gamma=0.1, method=clamp
# [AGT] [DEBUG   ] [02:13:08] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:13:08] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:13:08] Starting epoch 1
# [AGT] [DEBUG   ] [02:13:09] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:13:09] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:13:09] Starting epoch 2
# [AGT] [INFO    ] [02:13:10] Training batch 2: Network eval bounds=(0.4 , 0.44, 0.49), W0 Bound=0.0507
# [AGT] [INFO    ] [02:13:10] Final network eval: Network eval bounds=(0.37, 0.55, 0.73), W0 Bound=0.238
# [AGT] [INFO    ] [02:13:10] =================== Finished Poison Certified Training ===================
# [AGT] [INFO    ] [02:13:10] =================== Starting Poison Certified Training ===================
# [AGT] [DEBUG   ] [02:13:10] 	Optimizer params: n_epochs=2, learning_rate=5.0, l1_reg=0.0, l2_reg=0.0
# [AGT] [DEBUG   ] [02:13:10] 	Learning rate schedule: lr_decay=1.0, lr_min=0.001, early_stopping=False
# [AGT] [DEBUG   ] [02:13:10] 	Adversary feature-space budget: epsilon=0, k_poison=0
# [AGT] [DEBUG   ] [02:13:10] 	Adversary label-space budget: label_epsilon=0, label_k_poison=95, poison_target=-1
# [AGT] [DEBUG   ] [02:13:10] 	Clipping: gamma=0.1, method=clamp
# [AGT] [DEBUG   ] [02:13:10] 	Bounding methods: forward=interval, loss=cross_entropy, backward=interval
# [AGT] [WARNING ] [02:13:10] Dataloader has only one batch, effective batchsize may be smaller than expected.
# [AGT] [INFO    ] [02:13:10] Starting epoch 1
# [AGT] [DEBUG   ] [02:13:11] Initialising dataloader batchsize to 60000
# [AGT] [INFO    ] [02:13:11] Training batch 1: Network eval bounds=(0.12, 0.12, 0.12), W0 Bound=0.0
# [AGT] [INFO    ] [02:13:11] Starting epoch 2
# [AGT] [INFO    ] [02:13:12] Training batch 2: Network eval bounds=(0.39, 0.44, 0.5 ), W0 Bound=0.0566
# [AGT] [INFO    ] [02:13:12] Final network eval: Network eval bounds=(0.34, 0.55, 0.75), W0 Bound=0.266
# [AGT] [INFO    ] [02:13:12] =================== Finished Poison Certified Training ===================

# %%
palette = sns.color_palette(palette="Dark2", n_colors=12)
lb_color = list(iter(sns.color_palette(palette="deep")))[-1]
ub_color = list(iter(sns.color_palette(palette="deep")))[-2]

sns.set_theme(context="poster", style="whitegrid", font_scale=1.9)
mpl.rcParams["mathtext.fontset"] = "stix"
mpl.rcParams["font.family"] = "STIXGeneral"
labelsize = 22

fig, ax = plt.subplots(
    1,
    1,
    figsize=(10, 11),
)

colors = iter(palette)
for gamma, r in results.items():
    nom_accs = [res[1] for res in r.values()]
    cert_accs = [res[0] for res in r.values()]
    k_poisons = list(r.keys())
    color = next(colors)
    ax.plot(k_poisons, nom_accs, linestyle="--", color=color)
    ax.plot(k_poisons, cert_accs, label=fr"$\kappa={gamma if gamma != np.inf else '∞'}$", color=color)
    
plt.ylabel("Certified Accuracy", fontsize="large")
plt.xlabel("Attack Size ($m$)", fontsize="large")
plt.legend(handlelength=0.8)
plt.xlim(0, max(k_poisons))

plt.savefig(f".figures/mnist_poisoning.pdf", bbox_inches="tight", dpi=300)
